# %%
import cv2
from ultralytics import YOLO
import os
import json

# Load YOLO Models
main_object_model = YOLO("yolov8n.pt")  # For main objects
sub_object_model = YOLO("yolov8n.pt")  # For sub-objects (can be fine-tuned)

# Save JSON Output
def save_json(detections, output_path="outputs", frame_number=1):
    os.makedirs(output_path, exist_ok=True)
    json_file = os.path.join(output_path, f"frame_{frame_number}.json")
    with open(json_file, "w") as f:
        json.dump(detections, f, indent=4)
    print(f"Saved JSON for frame {frame_number} at {json_file}")

# Save Cropped Sub-Object Images
def save_cropped_images(frame, obj, output_folder="outputs"):
    os.makedirs(output_folder, exist_ok=True)
    if "subobject" in obj:
        sub_bbox = obj["subobject"]["bbox"]
        x1, y1, x2, y2 = map(int, sub_bbox)
        cropped_img = frame[y1:y2, x1:x2]
        sub_object_name = f"{obj['object']}_{obj['subobject']['object']}_{obj['id']}.jpg"
        image_path = os.path.join(output_folder, sub_object_name)
        cv2.imwrite(image_path, cropped_img)
        print(f"Saved cropped sub-object image: {image_path}")

def detect_sub_objects(frame, bbox):
    x1, y1, x2, y2 = map(int, bbox)
    roi = frame[y1:y2, x1:x2]  # Region of interest (cropped area)
    results = sub_object_model(roi)

    sub_objects = []
    sub_object_id = 0  # Counter for unique sub-object IDs

    for result in results:
        if not result.boxes:  # Check if there are no detections
            print("No sub-object detections in this ROI.")  # Debugging info
            continue

        for box in result.boxes:
            sub_bbox = box.xyxy[0].tolist()  # Bounding box of sub-object
            sub_label = sub_object_model.names[int(box.cls[0])]  # Sub-object name

            sub_object_id += 1  # Increment sub-object ID
            sub_objects.append({
                "object": sub_label,
                "id": sub_object_id,  # Assign unique ID
                "bbox": [int(sub_bbox[0]), int(sub_bbox[1]), int(sub_bbox[2]), int(sub_bbox[3])]
            })

    return sub_objects



def object_subobject_pipeline(video_path, output_folder="outputs"):
    os.makedirs(output_folder, exist_ok=True)
    video = cv2.VideoCapture(video_path)

    # Check if the video was successfully opened
    if not video.isOpened():
        print(f"Error: Could not open video file {video_path}")
        return

    frame_count = 0
    global_object_id = 0  # Counter for unique object IDs

    # Get total frames and frame rate (Optional for better debugging)
    total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Total frames in the video: {total_frames}")
    frame_rate = video.get(cv2.CAP_PROP_FPS)
    print(f"Frame rate: {frame_rate} FPS")

    while True:
        ret, frame = video.read()
        if not ret:
            print("No more frames or video ended.")
            break  # Exit the loop if no frame is retrieved

        frame_count += 1
        print(f"Processing Frame {frame_count}/{total_frames}...")

        # Check if the frame is valid
        if frame is None:
            print(f"Warning: Received an empty frame at Frame {frame_count}. Skipping.")
            continue

        # Detect Main Objects
        results = main_object_model(frame)
        detections = []

        for result in results:
            for box in result.boxes:
                bbox = box.xyxy[0].tolist()
                label = main_object_model.names[int(box.cls[0])]

                global_object_id += 1
                main_object = {
                    "object": label,
                    "id": global_object_id,
                    "bbox": [int(bbox[0]), int(bbox[1]), int(bbox[2]), int(bbox[3])]
                }

                # Detect Sub-Objects
                sub_objects = detect_sub_objects(frame, bbox)
                if sub_objects:
                    main_object["subobject"] = sub_objects[0]

                detections.append(main_object)

                # Save Sub-Object Images
                save_cropped_images(frame, main_object, output_folder)

        # Save JSON Output
        save_json(detections, output_folder, frame_number=frame_count)

        # Optional: Debug only first 5 frames for testing
        if frame_count > 5:
            print("Stopping after 5 frames for debugging.")
            break

    video.release()
    print("Processing Complete!")


# Run the Detection Pipeline
if __name__ == "__main__":
#     video_path = "data\zidane.jpg"  # Path to your video file
    video_path = "data/test_video.mp4"
    object_subobject_pipeline(video_path)
# Out:
# Total frames in the video: 660
# Frame rate: 23.976023976023978 FPS
# Processing Frame 1/660...
#
# 0: 384x640 24 cars, 4 trucks, 116.2ms
# Speed: 4.3ms preprocess, 116.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 128.0ms
# Speed: 5.0ms preprocess, 128.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 640x352 (no detections), 108.1ms
# Speed: 2.0ms preprocess, 108.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# No sub-object detections in this ROI.
#
# 0: 640x544 (no detections), 146.4ms
# Speed: 4.6ms preprocess, 146.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
# No sub-object detections in this ROI.
#
# 0: 448x640 (no detections), 96.1ms
# Speed: 2.6ms preprocess, 96.1ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 97.5ms
# Speed: 3.0ms preprocess, 97.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 544x640 (no detections), 165.4ms
# Speed: 6.7ms preprocess, 165.4ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 1 train, 122.4ms
# Speed: 4.0ms preprocess, 122.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved cropped sub-object image: outputs\car_train_7.jpg
#
# 0: 512x640 1 tv, 102.8ms
# Speed: 2.3ms preprocess, 102.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved cropped sub-object image: outputs\car_tv_8.jpg
#
# 0: 512x640 (no detections), 104.4ms
# Speed: 3.0ms preprocess, 104.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 640x384 (no detections), 107.7ms
# Speed: 2.9ms preprocess, 107.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 97.5ms
# Speed: 2.3ms preprocess, 97.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 106.7ms
# Speed: 3.6ms preprocess, 106.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 608x640 (no detections), 132.8ms
# Speed: 4.2ms preprocess, 132.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# No sub-object detections in this ROI.
#
# 0: 352x640 1 car, 114.7ms
# Speed: 4.9ms preprocess, 114.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# Saved cropped sub-object image: outputs\truck_car_14.jpg
#
# 0: 544x640 (no detections), 105.8ms
# Speed: 4.0ms preprocess, 105.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 640x640 (no detections), 181.8ms
# Speed: 4.8ms preprocess, 181.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# No sub-object detections in this ROI.
#
# 0: 544x640 (no detections), 124.0ms
# Speed: 5.2ms preprocess, 124.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 640x576 (no detections), 155.1ms
# Speed: 6.0ms preprocess, 155.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 93.1ms
# Speed: 2.6ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 640x640 1 bottle, 130.1ms
# Speed: 6.4ms preprocess, 130.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Saved cropped sub-object image: outputs\truck_bottle_20.jpg
#
# 0: 512x640 (no detections), 140.0ms
# Speed: 2.6ms preprocess, 140.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 640x640 1 bottle, 128.7ms
# Speed: 8.3ms preprocess, 128.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Saved cropped sub-object image: outputs\car_bottle_22.jpg
#
# 0: 416x640 (no detections), 119.4ms
# Speed: 3.1ms preprocess, 119.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# No sub-object detections in this ROI.
#
# 0: 544x640 (no detections), 114.3ms
# Speed: 4.8ms preprocess, 114.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 384x640 (no detections), 77.8ms
# Speed: 2.0ms preprocess, 77.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 94.1ms
# Speed: 3.1ms preprocess, 94.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 95.0ms
# Speed: 3.2ms preprocess, 95.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 576x640 (no detections), 152.1ms
# Speed: 4.8ms preprocess, 152.1ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# No sub-object detections in this ROI.
# Saved JSON for frame 1 at outputs\frame_1.json
# Processing Frame 2/660...
#
# 0: 384x640 25 cars, 4 trucks, 129.7ms
# Speed: 2.1ms preprocess, 129.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 110.4ms
# Speed: 3.1ms preprocess, 110.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 103.7ms
# Speed: 3.0ms preprocess, 103.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 640x352 (no detections), 94.6ms
# Speed: 3.0ms preprocess, 94.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# No sub-object detections in this ROI.
#
# 0: 448x640 (no detections), 84.6ms
# Speed: 2.1ms preprocess, 84.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# No sub-object detections in this ROI.
#
# 0: 640x384 (no detections), 76.8ms
# Speed: 3.0ms preprocess, 76.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# No sub-object detections in this ROI.
#
# 0: 640x512 (no detections), 126.1ms
# Speed: 4.0ms preprocess, 126.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 90.8ms
# Speed: 2.7ms preprocess, 90.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 544x640 (no detections), 120.9ms
# Speed: 4.5ms preprocess, 120.9ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 1 tv, 110.7ms
# Speed: 2.5ms preprocess, 110.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved cropped sub-object image: outputs\car_tv_37.jpg
#
# 0: 480x640 1 car, 101.6ms
# Speed: 3.7ms preprocess, 101.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved cropped sub-object image: outputs\car_car_38.jpg
#
# 0: 608x640 (no detections), 140.7ms
# Speed: 6.5ms preprocess, 140.7ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 640)
# No sub-object detections in this ROI.
#
# 0: 544x640 (no detections), 114.7ms
# Speed: 4.0ms preprocess, 114.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 576x640 (no detections), 126.1ms
# Speed: 7.6ms preprocess, 126.1ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 1 car, 124.6ms
# Speed: 3.6ms preprocess, 124.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved cropped sub-object image: outputs\car_car_42.jpg
#
# 0: 384x640 (no detections), 122.2ms
# Speed: 3.8ms preprocess, 122.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# No sub-object detections in this ROI.
#
# 0: 640x640 (no detections), 165.7ms
# Speed: 9.1ms preprocess, 165.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 156.0ms
# Speed: 3.0ms preprocess, 156.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 117.9ms
# Speed: 3.2ms preprocess, 117.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 640x640 (no detections), 139.1ms
# Speed: 8.0ms preprocess, 139.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No sub-object detections in this ROI.
#
# 0: 640x544 (no detections), 157.3ms
# Speed: 6.0ms preprocess, 157.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
# No sub-object detections in this ROI.
#
# 0: 352x640 (no detections), 112.6ms
# Speed: 3.1ms preprocess, 112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# No sub-object detections in this ROI.
#
# 0: 352x640 (no detections), 77.5ms
# Speed: 2.0ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# No sub-object detections in this ROI.
#
# 0: 416x640 1 car, 107.7ms
# Speed: 2.5ms preprocess, 107.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved cropped sub-object image: outputs\car_car_51.jpg
#
# 0: 608x640 (no detections), 132.7ms
# Speed: 5.0ms preprocess, 132.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# No sub-object detections in this ROI.
#
# 0: 448x640 (no detections), 90.9ms
# Speed: 3.0ms preprocess, 90.9ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# No sub-object detections in this ROI.
#
# 0: 640x512 1 car, 102.0ms
# Speed: 4.0ms preprocess, 102.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
# Saved cropped sub-object image: outputs\truck_car_54.jpg
#
# 0: 544x640 (no detections), 103.2ms
# Speed: 4.0ms preprocess, 103.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 576x640 (no detections), 110.8ms
# Speed: 5.6ms preprocess, 110.8ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 92.1ms
# Speed: 2.6ms preprocess, 92.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
# Saved JSON for frame 2 at outputs\frame_2.json
# Processing Frame 3/660...
#
# 0: 384x640 25 cars, 4 trucks, 83.2ms
# Speed: 2.0ms preprocess, 83.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 105.3ms
# Speed: 3.7ms preprocess, 105.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 97.2ms
# Speed: 3.2ms preprocess, 97.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 640x320 (no detections), 111.9ms
# Speed: 2.5ms preprocess, 111.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 320)
# No sub-object detections in this ROI.
#
# 0: 640x416 (no detections), 121.7ms
# Speed: 4.6ms preprocess, 121.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 88.4ms
# Speed: 3.4ms preprocess, 88.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 98.4ms
# Speed: 3.5ms preprocess, 98.4ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 95.2ms
# Speed: 3.0ms preprocess, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 98.2ms
# Speed: 3.5ms preprocess, 98.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 640x480 (no detections), 127.6ms
# Speed: 3.5ms preprocess, 127.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# No sub-object detections in this ROI.
#
# 0: 576x640 (no detections), 104.6ms
# Speed: 4.7ms preprocess, 104.6ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 83.3ms
# Speed: 2.0ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 100.3ms
# Speed: 3.0ms preprocess, 100.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 544x640 (no detections), 113.8ms
# Speed: 3.7ms preprocess, 113.8ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 576x640 (no detections), 95.7ms
# Speed: 4.5ms preprocess, 95.7ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# No sub-object detections in this ROI.
#
# 0: 576x640 (no detections), 100.7ms
# Speed: 6.0ms preprocess, 100.7ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# No sub-object detections in this ROI.
#
# 0: 608x640 (no detections), 103.2ms
# Speed: 5.7ms preprocess, 103.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# No sub-object detections in this ROI.
#
# 0: 544x640 (no detections), 95.9ms
# Speed: 4.1ms preprocess, 95.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 93.1ms
# Speed: 2.5ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 352x640 (no detections), 66.3ms
# Speed: 2.3ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 640)
# No sub-object detections in this ROI.
#
# 0: 416x640 1 car, 82.1ms
# Speed: 2.0ms preprocess, 82.1ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# Saved cropped sub-object image: outputs\car_car_77.jpg
#
# 0: 384x640 1 car, 1 suitcase, 86.4ms
# Speed: 3.0ms preprocess, 86.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved cropped sub-object image: outputs\truck_suitcase_78.jpg
#
# 0: 608x640 (no detections), 149.3ms
# Speed: 6.0ms preprocess, 149.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 640x384 (no detections), 118.5ms
# Speed: 2.1ms preprocess, 118.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# No sub-object detections in this ROI.
#
# 0: 640x544 (no detections), 133.3ms
# Speed: 4.6ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 544)
# No sub-object detections in this ROI.
#
# 0: 576x640 (no detections), 115.2ms
# Speed: 7.0ms preprocess, 115.2ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 104.2ms
# Speed: 3.2ms preprocess, 104.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 544x640 (no detections), 113.6ms
# Speed: 6.5ms preprocess, 113.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 416x640 1 car, 105.6ms
# Speed: 3.0ms preprocess, 105.6ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
# Saved cropped sub-object image: outputs\car_car_86.jpg
# Saved JSON for frame 3 at outputs\frame_3.json
# Processing Frame 4/660...
#
# 0: 384x640 28 cars, 3 trucks, 110.1ms
# Speed: 2.0ms preprocess, 110.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 car, 114.0ms
# Speed: 3.0ms preprocess, 114.0ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
# Saved cropped sub-object image: outputs\car_car_87.jpg
#
# 0: 512x640 (no detections), 112.3ms
# Speed: 3.0ms preprocess, 112.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 110.6ms
# Speed: 4.0ms preprocess, 110.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 640x416 (no detections), 80.8ms
# Speed: 3.0ms preprocess, 80.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 83.2ms
# Speed: 2.0ms preprocess, 83.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 640x320 (no detections), 79.1ms
# Speed: 2.5ms preprocess, 79.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 320)
# No sub-object detections in this ROI.
#
# 0: 640x448 (no detections), 134.6ms
# Speed: 3.0ms preprocess, 134.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
# No sub-object detections in this ROI.
#
# 0: 480x640 1 car, 107.1ms
# Speed: 3.0ms preprocess, 107.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved cropped sub-object image: outputs\car_car_94.jpg
#
# 0: 480x640 (no detections), 104.6ms
# Speed: 2.6ms preprocess, 104.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 89.3ms
# Speed: 2.5ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 544x640 (no detections), 106.2ms
# Speed: 4.0ms preprocess, 106.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 544x640 (no detections), 111.3ms
# Speed: 5.5ms preprocess, 111.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 116.0ms
# Speed: 2.0ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 86.0ms
# Speed: 3.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 576x640 (no detections), 100.4ms
# Speed: 4.5ms preprocess, 100.4ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 640)
# No sub-object detections in this ROI.
#
# 0: 608x640 1 person, 110.2ms
# Speed: 9.5ms preprocess, 110.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# Saved cropped sub-object image: outputs\car_person_102.jpg
#
# 0: 512x640 (no detections), 91.0ms
# Speed: 3.0ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 608x640 (no detections), 143.0ms
# Speed: 6.5ms preprocess, 143.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
# No sub-object detections in this ROI.
#
# 0: 384x640 1 car, 1 suitcase, 84.7ms
# Speed: 3.0ms preprocess, 84.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved cropped sub-object image: outputs\truck_car_105.jpg
#
# 0: 480x640 1 car, 1 oven, 150.0ms
# Speed: 3.0ms preprocess, 150.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved cropped sub-object image: outputs\car_oven_106.jpg
#
# 0: 352x640 (no detections), 79.6ms
# Speed: 2.0ms preprocess, 79.6ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
# No sub-object detections in this ROI.
#
# 0: 640x640 (no detections), 154.2ms
# Speed: 7.5ms preprocess, 154.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# No sub-object detections in this ROI.
#
# 0: 448x640 (no detections), 119.6ms
# Speed: 2.0ms preprocess, 119.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# No sub-object detections in this ROI.
#
# 0: 640x544 (no detections), 161.8ms
# Speed: 6.1ms preprocess, 161.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 544)
# No sub-object detections in this ROI.
#
# 0: 448x640 (no detections), 79.1ms
# Speed: 2.0ms preprocess, 79.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# No sub-object detections in this ROI.
#
# 0: 416x640 1 car, 119.1ms
# Speed: 1.0ms preprocess, 119.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved cropped sub-object image: outputs\car_car_112.jpg
#
# 0: 512x640 (no detections), 103.2ms
# Speed: 2.0ms preprocess, 103.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 576x640 (no detections), 118.0ms
# Speed: 5.5ms preprocess, 118.0ms inference, 1.5ms postprocess per image at shape (1, 3, 576, 640)
# No sub-object detections in this ROI.
#
# 0: 544x640 (no detections), 115.4ms
# Speed: 5.0ms preprocess, 115.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 119.7ms
# Speed: 3.6ms preprocess, 119.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 116.3ms
# Speed: 3.0ms preprocess, 116.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
# Saved JSON for frame 4 at outputs\frame_4.json
# Processing Frame 5/660...
#
# 0: 384x640 28 cars, 1 bus, 3 trucks, 112.7ms
# Speed: 3.0ms preprocess, 112.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 124.4ms
# Speed: 3.5ms preprocess, 124.4ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 148.9ms
# Speed: 3.5ms preprocess, 148.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 640x448 (no detections), 116.4ms
# Speed: 3.0ms preprocess, 116.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 117.9ms
# Speed: 3.5ms preprocess, 117.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 1 car, 144.4ms
# Speed: 4.6ms preprocess, 144.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved cropped sub-object image: outputs\car_car_122.jpg
#
# 0: 480x640 (no detections), 133.7ms
# Speed: 4.5ms preprocess, 133.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 640x384 (no detections), 155.8ms
# Speed: 3.0ms preprocess, 155.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 120.0ms
# Speed: 3.6ms preprocess, 120.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 124.0ms
# Speed: 3.6ms preprocess, 124.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 544x640 (no detections), 111.1ms
# Speed: 5.5ms preprocess, 111.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 544x640 (no detections), 101.1ms
# Speed: 6.7ms preprocess, 101.1ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 608x640 1 bench, 113.6ms
# Speed: 6.5ms preprocess, 113.6ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
# Saved cropped sub-object image: outputs\car_bench_129.jpg
#
# 0: 480x640 (no detections), 101.7ms
# Speed: 3.0ms preprocess, 101.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 96.3ms
# Speed: 4.1ms preprocess, 96.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 640x288 1 train, 104.1ms
# Speed: 3.7ms preprocess, 104.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 288)
# Saved cropped sub-object image: outputs\truck_train_132.jpg
#
# 0: 608x640 (no detections), 122.0ms
# Speed: 7.8ms preprocess, 122.0ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 640)
# No sub-object detections in this ROI.
#
# 0: 608x640 (no detections), 153.8ms
# Speed: 6.5ms preprocess, 153.8ms inference, 1.4ms postprocess per image at shape (1, 3, 608, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 103.8ms
# Speed: 3.5ms preprocess, 103.8ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 320x640 1 car, 107.0ms
# Speed: 2.0ms preprocess, 107.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# Saved cropped sub-object image: outputs\truck_car_136.jpg
#
# 0: 544x640 1 train, 126.3ms
# Speed: 5.5ms preprocess, 126.3ms inference, 2.5ms postprocess per image at shape (1, 3, 544, 640)
# Saved cropped sub-object image: outputs\car_train_137.jpg
#
# 0: 416x640 1 car, 103.0ms
# Speed: 3.9ms preprocess, 103.0ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
# Saved cropped sub-object image: outputs\car_car_138.jpg
#
# 0: 640x576 (no detections), 144.0ms
# Speed: 7.6ms preprocess, 144.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
# No sub-object detections in this ROI.
#
# 0: 448x640 (no detections), 94.1ms
# Speed: 3.0ms preprocess, 94.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# No sub-object detections in this ROI.
#
# 0: 640x640 (no detections), 154.6ms
# Speed: 7.4ms preprocess, 154.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 132.5ms
# Speed: 3.0ms preprocess, 132.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 107.9ms
# Speed: 3.0ms preprocess, 107.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 640x288 (no detections), 79.0ms
# Speed: 2.9ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 288)
# No sub-object detections in this ROI.
#
# 0: 384x640 (no detections), 119.4ms
# Speed: 3.0ms preprocess, 119.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# No sub-object detections in this ROI.
#
# 0: 416x640 1 car, 107.3ms
# Speed: 3.6ms preprocess, 107.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved cropped sub-object image: outputs\car_car_146.jpg
#
# 0: 640x288 1 train, 96.2ms
# Speed: 2.0ms preprocess, 96.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 288)
# Saved cropped sub-object image: outputs\bus_train_147.jpg
#
# 0: 576x640 (no detections), 152.9ms
# Speed: 7.5ms preprocess, 152.9ms inference, 1.6ms postprocess per image at shape (1, 3, 576, 640)
# No sub-object detections in this ROI.
#
# 0: 448x640 (no detections), 103.2ms
# Speed: 3.0ms preprocess, 103.2ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# No sub-object detections in this ROI.
# Saved JSON for frame 5 at outputs\frame_5.json
# Processing Frame 6/660...
#
# 0: 384x640 29 cars, 4 trucks, 122.4ms
# Speed: 2.5ms preprocess, 122.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 car, 115.7ms
# Speed: 3.5ms preprocess, 115.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved cropped sub-object image: outputs\car_car_150.jpg
#
# 0: 512x640 1 car, 116.7ms
# Speed: 3.5ms preprocess, 116.7ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 640)
# Saved cropped sub-object image: outputs\car_car_151.jpg
#
# 0: 512x640 (no detections), 115.9ms
# Speed: 3.6ms preprocess, 115.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 640x448 (no detections), 193.7ms
# Speed: 5.7ms preprocess, 193.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
# No sub-object detections in this ROI.
#
# 0: 480x640 1 car, 134.4ms
# Speed: 4.5ms preprocess, 134.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Saved cropped sub-object image: outputs\car_car_154.jpg
#
# 0: 480x640 (no detections), 112.9ms
# Speed: 3.5ms preprocess, 112.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 217.1ms
# Speed: 8.9ms preprocess, 217.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 640x352 (no detections), 211.7ms
# Speed: 2.5ms preprocess, 211.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 132.3ms
# Speed: 4.3ms preprocess, 132.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 1 tv, 118.1ms
# Speed: 3.9ms preprocess, 118.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved cropped sub-object image: outputs\car_tv_159.jpg
#
# 0: 544x640 (no detections), 120.5ms
# Speed: 6.5ms preprocess, 120.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 608x640 (no detections), 166.0ms
# Speed: 8.5ms preprocess, 166.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 148.5ms
# Speed: 3.5ms preprocess, 148.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 640x608 (no detections), 188.0ms
# Speed: 9.3ms preprocess, 188.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 608)
# No sub-object detections in this ROI.
#
# 0: 480x640 (no detections), 120.6ms
# Speed: 4.0ms preprocess, 120.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# No sub-object detections in this ROI.
#
# 0: 608x640 (no detections), 141.5ms
# Speed: 8.1ms preprocess, 141.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 120.9ms
# Speed: 3.5ms preprocess, 120.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 640x288 (no detections), 81.4ms
# Speed: 3.5ms preprocess, 81.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 288)
# No sub-object detections in this ROI.
#
# 0: 544x640 (no detections), 119.9ms
# Speed: 5.8ms preprocess, 119.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# No sub-object detections in this ROI.
#
# 0: 640x576 (no detections), 195.4ms
# Speed: 5.6ms preprocess, 195.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
# No sub-object detections in this ROI.
#
# 0: 416x640 1 car, 113.7ms
# Speed: 2.7ms preprocess, 113.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Saved cropped sub-object image: outputs\car_car_170.jpg
#
# 0: 640x320 (no detections), 158.0ms
# Speed: 3.9ms preprocess, 158.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 320)
# No sub-object detections in this ROI.
#
# 0: 320x640 1 car, 149.4ms
# Speed: 4.1ms preprocess, 149.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# Saved cropped sub-object image: outputs\truck_car_172.jpg
#
# 0: 416x640 (no detections), 117.7ms
# Speed: 4.0ms preprocess, 117.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# No sub-object detections in this ROI.
#
# 0: 448x640 (no detections), 157.5ms
# Speed: 3.1ms preprocess, 157.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 157.7ms
# Speed: 3.1ms preprocess, 157.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 352x640 (no detections), 128.9ms
# Speed: 3.0ms preprocess, 128.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 130.4ms
# Speed: 3.5ms preprocess, 130.4ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
#
# 0: 448x640 1 car, 123.8ms
# Speed: 3.5ms preprocess, 123.8ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Saved cropped sub-object image: outputs\car_car_178.jpg
#
# 0: 640x416 (no detections), 130.6ms
# Speed: 3.0ms preprocess, 130.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
# No sub-object detections in this ROI.
#
# 0: 608x640 (no detections), 162.9ms
# Speed: 5.8ms preprocess, 162.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# No sub-object detections in this ROI.
#
# 0: 576x640 (no detections), 190.2ms
# Speed: 6.5ms preprocess, 190.2ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# No sub-object detections in this ROI.
#
# 0: 512x640 (no detections), 141.5ms
# Speed: 4.5ms preprocess, 141.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# No sub-object detections in this ROI.
# Saved JSON for frame 6 at outputs\frame_6.json
# Stopping after 5 frames for debugging.
# Processing Complete!
